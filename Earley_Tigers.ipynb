# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## We begin by importing the data into a Data Frame. We explore the data using the describe command for statistical information and the isnull command to see if there are any null values.

# %%
pitcher = pd.read_csv('/Users/williamearley/Detroit Tigers/PitcherData.csv')

# %%
# Making sure we can see all of the columns
pd.set_option('display.max_columns', None)

# %%
pitcher.head(5)
# Out:
#    GameId     Role PitcherHandedness Delivery  ReleaseSpeed  ZoneSpeed  \
# 0  717247  Pitcher                 R       WU     92.883598  85.358162
# 1  716775  Pitcher                 R       WU     92.162498  82.678711
# 2  716858  Pitcher                 R       WU     82.715797  76.270004
# 3  717247  Pitcher                 R       WU     83.119797  75.655327
# 4  716775  Pitcher                 R       WU     82.492897  74.397636
#
#    PitchVerticalApproachAngle  ReleaseExtension  ReleaseHeight  ReleaseSide  \
# 0                    -5.26402          7.200283        5.68847     -1.32301
# 1                    -5.50739          7.074602        5.78597     -1.85525
# 2                    -6.89922          6.584419        5.63218     -2.29365
# 3                    -5.24281          6.893004        5.59272     -1.73077
# 4                    -7.73599          6.785694        5.60639     -2.27405
#
#    ArmAngleBR  ArmSlotBR  StrideLength  StrideLengthPercentHeight  \
# 0  104.899590  45.482530      6.234744                   0.959191
# 1   97.735704  45.769597      5.785254                   0.890039
# 2   93.595188  34.566340      5.763707                   0.886724
# 3   96.388369  36.804432      5.957531                   0.916543
# 4   93.812173  34.557654      5.656930                   0.870297
#
#    StrideWidth  TimeToPlate  PeakHipsVeloX  PeakPitchHandVeloX  DLHipRotMin  \
# 0     0.480582     1.794048       9.999728           74.488926   -57.704386
# 1     0.457357     1.727100       9.242676           73.800552   -57.276927
# 2     0.511941     1.686831       8.663261           73.844070   -50.011344
# 3     0.511139     1.815403       9.055229           74.069121   -57.962970
# 4     0.568982     1.739589       8.495374           73.059455   -57.106482
#
#     HSSepMin    PARotMax  PAScapRetMin  SLKneeFlexFP  PAElbowFlexBR  \
# 0 -59.436962  184.867034    -26.459514     33.558428      46.156729
# 1 -57.582635  183.756854    -48.689772     36.399829      48.956994
# 2 -58.600042  177.195048    -37.923668     45.693107      47.207844
# 3 -55.065895  178.878454    -32.900200     54.958079      41.582631
# 4 -49.458994  179.567484    -31.854868     36.941969      45.594204
#
#    SLKneeFlexBR  TorsoFBBR  TorsoSBBR  PeakMomDL  PeakMomSL  PeakMomTorso  \
# 0     61.829131  35.014744 -19.803716  59.076818  65.505386    178.474295
# 1     63.961833  33.845853 -20.061510  58.735936  61.773624    156.940774
# 2     56.650464  33.564136 -20.971002  55.022454  63.380261    145.438170
# 3     58.934772  33.622471 -21.629818  60.764912  62.610400    168.421515
# 4     61.485206  33.593086 -22.584209  56.903023  61.471940    158.717514
#
#    PeakMomLFA  PeakMomLUA  PeakMomPFA  PeakMomPUA  PeakMomTotalBody  \
# 0   14.589029   20.879261   25.940629   33.364805        316.155373
# 1   14.079443   19.891426   25.076940   32.904583        301.055415
# 2   13.719164   19.659263   25.668376   32.653768        294.829938
# 3   13.169548   19.434903   25.244505   33.298595        302.047333
# 4   13.388108   18.683585   25.102197   32.331211        303.595953
#
#    PeakMomTimeDL  PeakMomTimeSL  PeakMomTimeTorso  PeakMomTimeLFA  \
# 0      -0.225082      -0.278411         -0.071761       -0.118424
# 1      -0.198722      -0.422037         -0.125395       -0.148726
# 2      -0.156931      -0.376911         -0.150265       -0.166930
# 3      -0.211766      -0.388417         -0.071779       -0.115108
# 4      -0.158551      -0.368511         -0.131889       -0.161884
#
#    PeakMomTimeLUA  PeakMomTimePFA  PeakMomTimePUA  PeakMomTimeTotalBody  \
# 0       -0.115091       -0.005100       -0.051763             -0.078427
# 1       -0.118729       -0.002071       -0.048734             -0.135394
# 2       -0.110269       -0.010278       -0.050274             -0.160264
# 3       -0.115108       -0.008451       -0.055113             -0.078445
# 4       -0.121891       -0.015246       -0.048572             -0.138554
#
#    PeakPelvisRotVelo  PeakPelvisRotVeloTime  PeakChestRotVelo  \
# 0         580.134192              -0.138422       1051.790412
# 1         496.175175              -0.158725       1027.137579
# 2         530.217031              -0.196927       1030.521089
# 3         633.641588              -0.131773       1075.259760
# 4         582.870626              -0.128556       1001.115499
#
#    PeakChestRotVeloTime  PeakElbowExtVelo  PeakElbowExtVeloTime  \
# 0             -0.098426       1551.117321             -0.008433
# 1             -0.102063       1415.418660             -0.012071
# 2             -0.100270       1444.905634             -0.016944
# 3             -0.098443       1429.031908             -0.011784
# 4             -0.105228       1396.443455             -0.015246
#
#    PeakShoulderIRVelo  PeakShoulderIRVeloTime  PelvisChestPeakTimeDiff  \
# 0         2739.631800                0.014898                 0.039996
# 1         3244.898378                0.011261                 0.056662
# 2         2843.902854                0.009720                 0.096657
# 3         3225.623090                0.011547                 0.033330
# 4         2964.765619                0.011416                 0.023329
#
#    PeakSLKneeExtVelo  ClosingSpeed  ClosingTime  TimeFirstMove  \
# 0         -95.431603    519.237125     0.136655      -1.378319
# 1         -83.259474    466.447877     0.143322      -1.301965
# 2        -111.203636    488.495351     0.149986      -1.220166
# 3        -219.777620    539.613373     0.136654      -1.348332
# 4         -37.581384    439.242897     0.149970      -1.265003
#
#    TimeHandSeparation  TimePeakKneeLift  TimeFootPlant   TimeMER PitchType  \
# 0           -0.498392         -0.841697      -0.151755 -0.031765        FB
# 1           -0.532028         -0.802006      -0.155392 -0.035402        FB
# 2           -0.523564         -0.773540      -0.086937 -0.036942       NaN
# 3           -0.498408         -0.821712      -0.078445 -0.035115        SL
# 4           -0.535145         -0.781763      -0.145221 -0.038574        SL
#
#       SpinRate  SpinDirection  InducedVertBreak  SpinEfficiency  PitchCount
# 0  2010.934814     198.274002         15.237906        0.981800           1
# 1  1991.656250     186.020004         18.172521        0.969281           1
# 2  2211.644287     134.322998          9.893006        0.381183           1
# 3  2233.343750     122.036003          9.656799        0.366566           2
# 4  2300.342041     114.580002          7.594166        0.465045           2

# %%
pitcher.describe()
# Out:
#               GameId  ReleaseSpeed   ZoneSpeed  PitchVerticalApproachAngle  \
# count     302.000000    302.000000  302.000000                  302.000000
# mean   717124.188742     86.098194   79.232781                   -6.693533
# std       217.284083      9.087045    8.230610                    1.916353
# min    716775.000000     76.282402   70.297806                  -11.787500
# 25%    717033.000000     80.619299   74.485813                   -7.767655
# 50%    717103.000000     82.496098   75.935085                   -6.513370
# 75%    717286.000000     92.241074   84.437202                   -5.267535
# max    717442.000000    144.428101  131.757385                   -2.765060
#
#        ReleaseExtension  ReleaseHeight  ReleaseSide  ArmAngleBR   ArmSlotBR  \
# count        299.000000     302.000000   302.000000  302.000000  302.000000
# mean           6.883590       5.645325    -1.923332   97.561106   38.603067
# std            0.543692       0.408736     0.336387    7.474200    4.897092
# min            6.322228       5.301700    -3.527640   86.735665   28.722598
# 25%            6.640818       5.518960    -2.171350   94.232070   35.282521
# 50%            6.789382       5.574060    -1.896475   96.652319   38.067818
# 75%            6.975887       5.650313    -1.690458   99.570950   40.995392
# max           10.788990       8.534325    -1.037170  150.886345   66.478051
#
#        StrideLength  ...  TimeFirstMove  TimeHandSeparation  TimePeakKneeLift  \
# count    302.000000  ...     302.000000          299.000000        302.000000
# mean       6.032899  ...      -1.249791           -0.509188         -0.783722
# std        0.455390  ...       0.074995            0.016496          0.038428
# min        5.463412  ...      -1.400111           -0.615597         -0.858024
# 25%        5.866754  ...      -1.299560           -0.517671         -0.813110
# 50%        5.981866  ...      -1.260016           -0.506154         -0.785802
# 75%        6.111478  ...      -1.226028           -0.497554         -0.758352
# max        9.430789  ...      -0.895563           -0.479368         -0.660246
#
#        TimeFootPlant     TimeMER     SpinRate  SpinDirection  \
# count     302.000000  302.000000   302.000000     302.000000
# mean       -0.113843   -0.034303  2167.310349     132.555220
# std         0.033478    0.002128   182.311150      62.626109
# min        -0.174190   -0.040120  1299.569580      13.019500
# 25%        -0.140729   -0.035777  2114.034913     108.632500
# 50%        -0.128234   -0.034181  2196.551147     134.225998
# 75%        -0.082317   -0.032754  2269.856079     190.082245
# max        -0.041021   -0.028713  2526.262207     263.348999
#
#        InducedVertBreak  SpinEfficiency  PitchCount
# count        302.000000      297.000000  302.000000
# mean           6.612398        0.671634   25.076159
# std           10.129514        0.243631   16.346258
# min          -14.767908        0.298495    1.000000
# 25%            4.550314        0.418503   11.000000
# 50%            9.650246        0.805326   23.000000
# 75%           14.658138        0.899199   37.000000
# max           19.807076        0.992133   65.000000
#
# [8 rows x 62 columns]

# %%
pitcher.isnull().sum()
# Out:
# GameId               0
# Role                 0
# PitcherHandedness    0
# Delivery             0
# ReleaseSpeed         0
#                     ..
# SpinRate             0
# SpinDirection        0
# InducedVertBreak     0
# SpinEfficiency       5
# PitchCount           0
# Length: 66, dtype: int64

# %% [markdown]
# ## A lot of times it can be helpful to get a visual for the question at hand. Here we see box plots for each different pitch type thrown by the pitcher. We see that the fastball (FB) seems to have the greatest variance, potentially due to the outliers at the top. Let's do some more digging and see why this might be.

# %%
# Box plot to visualize variance in fastball velocities
plt.figure(figsize=(12, 10))
sns.boxplot(x='PitchType', y='ReleaseSpeed', data=pitcher)
plt.title('Variance in Pitch Type Velocities')
plt.xlabel('Pitch Type')
plt.ylabel('Release Speed')
plt.show()

# %%
# Calculate variance in fastball velocities
fastball_variances = pitcher[pitcher['PitchType'] == 'FB']['ReleaseSpeed'].var()

# Generate short report
report = f"The pitcher exhibits high variance in fastball velocities with a variance value of {fastball_variances:.2f}."
print(report)
# Out:
# The pitcher exhibits high variance in fastball velocities with a variance value of 78.90.

# %%
pitcher_sorted = pitcher.sort_values(by='ReleaseSpeed', ascending=False)

# %% [markdown]
# ### Below we see the pitches with the 10 fastest release speeds. The top 6 have release speeds above 124 mph and zone speeds above 115 mph. These both seem a bit unrealistic and might imply an error in the radar gun. Six of the ten were fastballs.

# %%
pitcher_sorted.head(10)
# Out:
#      GameId     Role PitcherHandedness Delivery  ReleaseSpeed   ZoneSpeed  \
# 60   716775  Pitcher                 R       WU    144.428101  130.805454
# 44   717247  Pitcher                 R       WU    142.564201  131.757385
# 76   717442  Pitcher                 R       WU    136.999203  124.810959
# 68   717247  Pitcher                 R        S    130.232552  119.658565
# 84   717442  Pitcher                 R       WU    124.673401  114.288391
# 52   716775  Pitcher                 R       WU    124.531952  115.180698
# 16   717247  Pitcher                 R       WU     97.876701   89.004723
# 14   717247  Pitcher                 R       WU     97.401299   88.727501
# 257  716858  Pitcher                 R       WU     97.354202   90.105560
# 11   717247  Pitcher                 R       WU     97.045502   88.107910
#
#      PitchVerticalApproachAngle  ReleaseExtension  ReleaseHeight  ReleaseSide  \
# 60                    -7.608690         10.068470       8.486535    -3.146085
# 44                    -7.455015         10.323760       8.302200    -2.494560
# 76                    -6.516480         10.788990       8.534325    -1.985340
# 68                    -9.263970         10.236787       8.232645    -2.469285
# 84                    -8.545980         10.468919       8.437875    -2.738355
# 52                    -9.994470          9.944464       8.475315    -3.527640
# 16                    -4.742900          6.984393       5.516840    -1.729450
# 14                    -4.490610          7.129623       5.566230    -1.667700
# 257                   -4.690550          6.691256       5.631090    -2.038230
# 11                    -4.156420          7.090123       5.591730    -1.704550
#
#      ArmAngleBR  ArmSlotBR  StrideLength  StrideLengthPercentHeight  \
# 60   132.904399  48.460830      8.738614                   1.344402
# 44   143.240333  52.158162      8.935462                   1.374686
# 76   150.886345  66.478051      9.430789                   1.450891
# 68   147.708293  53.511116      9.082756                   1.397347
# 84   146.082944  55.776152      9.130152                   1.404639
# 52   136.590380  50.873267      8.621408                   1.326371
# 16    91.748460  33.812224      6.096286                   0.937890
# 14    91.478616  34.962947      6.232391                   0.958829
# 257   89.791053  33.413084      5.917740                   0.910422
# 11    94.008651  36.373097      6.080550                   0.935469
#
#      StrideWidth  TimeToPlate  PeakHipsVeloX  PeakPitchHandVeloX  DLHipRotMin  \
# 60      0.426796     2.528760      13.435008          113.485368   -85.341648
# 44      0.624250     2.707715      14.136546          110.613276   -86.769015
# 76      0.530655     2.656222      15.911239          110.476449   -68.485517
# 68      1.114424     2.418464      13.948349          110.799358   -87.093136
# 84      0.937306     2.664765      14.789205          109.591863   -85.006061
# 52      0.989183     2.628541      12.268701          109.923887   -84.996288
# 16      0.356713     1.746958       9.934898           76.586307   -57.878808
# 14      0.346584     1.756418       9.824858           75.475082   -57.899852
# 257     0.293796     1.708041       9.119435           76.714967   -57.190356
# 11      0.405379     1.752434       9.991047           75.761596   -58.045865
#
#       HSSepMin    PARotMax  PAScapRetMin  SLKneeFlexFP  PAElbowFlexBR  \
# 60  -87.864937  270.450604    -59.166280     40.667795      70.559456
# 44  -91.658517  271.423459    -43.550100     53.864817      71.486830
# 76  -86.916206  272.998285    -46.729251     81.108770      71.732824
# 68  -84.145125  275.453715    -51.164239     52.915363      68.529689
# 84  -86.772085  267.603664    -52.935998     75.523086      67.714264
# 52  -77.590639  266.822544    -48.573221     49.352790      74.948856
# 16  -64.509699  182.210755    -37.760458     28.918025      47.266474
# 14  -62.259627  182.626229    -33.038938     37.032988      46.821193
# 257 -60.756966  184.920583    -30.935716     48.455120      47.891178
# 11  -61.723303  184.503804    -41.683864     39.242601      46.848158
#
#      SLKneeFlexBR  TorsoFBBR  TorsoSBBR  PeakMomDL  PeakMomSL  PeakMomTorso  \
# 60      73.317525  51.124386 -27.220061  88.864974  93.564100    218.101304
# 44      85.095044  52.417045 -26.783777  88.282098  94.105101    248.683414
# 76      90.111403  52.418748 -32.928618  95.625304  94.310047    235.341869
# 68      87.035414  49.320784 -26.587892  93.734994  96.340628    248.423674
# 84      85.742782  50.610578 -31.641376  90.892455  91.804924    241.133956
# 52      90.347262  48.679886 -34.314545  89.593373  96.145723    237.174721
# 16      51.903871  34.630981 -17.560559  63.639610  67.022312    164.418820
# 14      44.993075  34.617950 -17.166733  62.428821  68.695559    165.045901
# 257     45.637427  35.484187 -22.744159  60.571277  66.779345    153.179670
# 11      52.680674  34.425399 -18.910345  62.440124  66.945218    165.632830
#
#      PeakMomLFA  PeakMomLUA  PeakMomPFA  PeakMomPUA  PeakMomTotalBody  \
# 60    21.101918   29.988635   38.779546   50.737060        428.815710
# 44    21.122865   31.493470   38.321411   51.911626        441.221689
# 76    19.587207   30.310205   36.651398   49.287246        441.986210
# 68    21.198817   30.344178   37.763955   49.441414        473.683470
# 84    19.829670   28.700753   36.434851   49.191232        459.834100
# 52    20.412874   27.919746   37.947464   49.881006        447.334272
# 16    14.468818   20.903973   26.096469   35.776415        306.134113
# 14    14.620643   20.784346   25.679427   35.932802        306.704352
# 257   14.597525   21.197665   26.226512   35.134054        287.080856
# 11    14.093855   20.732107   25.971664   35.643418        299.105287
#
#      PeakMomTimeDL  PeakMomTimeSL  PeakMomTimeTorso  PeakMomTimeLFA  \
# 60       -0.297597      -0.592572         -0.182609       -0.177608
# 44       -0.315340      -0.505321         -0.170353       -0.170353
# 76       -0.369679      -0.374678         -0.169697       -0.169697
# 68       -0.296180      -0.576155         -0.166193       -0.181192
# 84       -0.346600      -0.356599         -0.196613       -0.236609
# 52       -0.296398      -0.581371         -0.191407       -0.246402
# 16       -0.200564      -0.363883         -0.127237       -0.110572
# 14       -0.201716      -0.325032         -0.065069       -0.115062
# 257      -0.186185      -0.359502         -0.129524       -0.116192
# 11       -0.202590      -0.259252         -0.065935       -0.109265
#
#      PeakMomTimeLUA  PeakMomTimePFA  PeakMomTimePUA  PeakMomTimeTotalBody  \
# 60        -0.172608       -0.017622       -0.072618             -0.282598
# 44        -0.165355       -0.020368       -0.075363             -0.175354
# 76        -0.169697       -0.009713       -0.069707             -0.219692
# 68        -0.176192       -0.021206       -0.076201             -0.171193
# 84        -0.171616       -0.021629       -0.071624             -0.196613
# 52        -0.176409       -0.021423       -0.076417             -0.201406
# 16        -0.107239       -0.010581       -0.047245             -0.137237
# 14        -0.111729        0.001588       -0.048405             -0.131726
# 257       -0.109526       -0.009535       -0.046198             -0.166187
# 11        -0.112598       -0.012607       -0.049270             -0.162594
#
#      PeakPelvisRotVelo  PeakPelvisRotVeloTime  PeakChestRotVelo  \
# 60          761.886914              -0.197607       1655.178972
# 44         1022.975418              -0.195352       1766.384225
# 76          705.882472              -0.189695       1517.661949
# 68          992.454750              -0.211189       1715.166731
# 84          775.215816              -0.181615       1548.090556
# 52          751.492312              -0.176409       1524.535489
# 16          617.096035              -0.133903       1271.569698
# 14          609.137125              -0.128394       1241.837132
# 257         568.301817              -0.119525       1161.902161
# 11          614.461737              -0.129263       1123.914991
#
#      PeakChestRotVeloTime  PeakElbowExtVelo  PeakElbowExtVeloTime  \
# 60              -0.137611       2153.600068             -0.027621
# 44              -0.150355       2335.910767             -0.020368
# 76              -0.159698       2448.744053             -0.009713
# 68              -0.151195       2228.549609             -0.021206
# 84              -0.161617       2360.834161             -0.016630
# 52              -0.146410       2111.891660             -0.026422
# 16              -0.090574       1505.084783             -0.010581
# 14              -0.095065       1482.581716             -0.011744
# 257             -0.089528       1563.815269             -0.012868
# 11              -0.095933       1530.587887             -0.012607
#
#      PeakShoulderIRVelo  PeakShoulderIRVeloTime  PelvisChestPeakTimeDiff  \
# 60          4624.142792                0.017375                 0.059996
# 44          4552.015817                0.019628                 0.044997
# 76          4679.925210                0.020284                 0.029997
# 68          4343.800385                0.013790                 0.059994
# 84          4979.081012                0.018368                 0.019998
# 52          4394.085309                0.013574                 0.029999
# 16          2905.987285                0.012750                 0.043329
# 14          2932.468246                0.011587                 0.033329
# 257         3209.670643                0.010463                 0.029997
# 11          3199.047552                0.014057                 0.033330
#
#      PeakSLKneeExtVelo  ClosingSpeed  ClosingTime  TimeFirstMove  \
# 60         -214.017544    761.894726     0.204983      -1.281636
# 44         -234.259045    839.639090     0.199982      -1.400111
# 76          -34.059865    483.255480     0.334968      -1.346347
# 68         -375.055093    800.143403     0.194982      -1.167363
# 84           23.736026    773.790594     0.214980      -1.310969
# 52         -200.600301    688.184520     0.224979      -1.287500
# 16         -173.863018    605.745918     0.129988      -1.350462
# 14         -265.373980    582.913893     0.133314      -1.358230
# 257        -106.938882    558.842259     0.133321      -1.312743
# 11         -193.693583    597.483188     0.133321      -1.352487
#
#      TimeHandSeparation  TimePeakKneeLift  TimeFootPlant   TimeMER PitchType  \
# 60            -0.495039         -0.751683      -0.168401 -0.035080        FB
# 44            -0.503532         -0.813502      -0.143567 -0.033577        FB
# 76            -0.509760         -0.846395      -0.069802 -0.033139        FB
# 68            -0.504091         -0.744069      -0.127460 -0.034135        CH
# 84            -0.501042         -0.827680      -0.054415 -0.034417        SL
# 52            -0.517569         -0.794211      -0.144270 -0.037613        SL
# 16            -0.487205         -0.797178      -0.150569 -0.030579        FB
# 14            -0.488343         -0.818300      -0.138392 -0.031741        FB
# 257           -0.506154         -0.796126      -0.076195 -0.032866       NaN
# 11            -0.492564         -0.815868      -0.142595 -0.032605        FB
#
#         SpinRate  SpinDirection  InducedVertBreak  SpinEfficiency  PitchCount
# 60   2266.403809     199.283005         16.558896        0.857489           7
# 44   2005.884521     188.897995         14.856069        0.919497          10
# 76   2017.516113     192.552002         16.332955        0.970398          11
# 68   1299.569580     263.348999          3.304531        0.976551          13
# 84   2078.108887     142.119003         11.697480        0.351869          12
# 52   2205.879639     151.835007         12.660908        0.407497           4
# 16   2152.431152     199.927994         15.017406        0.877826           6
# 14   2158.581055     195.865997         14.577360        0.893480           5
# 257  2223.634033     185.240005         14.788816        0.814496          31
# 11   2166.217773     196.639999         15.980596        0.952905           4

# %% [markdown]
# ## Another method we can pursue is feature importance. Here we use a Random Forrest Regressor to identify the features that most impact Release Speed.

# %%
# For this analysis we only want to know about the fastballs, so we remove the pitches that weren't "FB".
fastball_only = pitcher[pitcher['PitchType'] == 'FB']

# %%
fastball_only.head(5)
# Out:
#     GameId     Role PitcherHandedness Delivery  ReleaseSpeed  ZoneSpeed  \
# 0   717247  Pitcher                 R       WU     92.883598  85.358162
# 1   716775  Pitcher                 R       WU     92.162498  82.678711
# 8   717299  Pitcher                 R       WU     91.378700  83.668266
# 9   717442  Pitcher                 R       WU     94.797997  86.015198
# 10  717299  Pitcher                 R       WU     91.773499  84.278610
#
#     PitchVerticalApproachAngle  ReleaseExtension  ReleaseHeight  ReleaseSide  \
# 0                     -5.26402          7.200283        5.68847     -1.32301
# 1                     -5.50739          7.074602        5.78597     -1.85525
# 8                     -3.70165          6.875530        5.66476     -1.37897
# 9                     -4.85433          7.120858        5.65724     -1.32767
# 10                    -5.13359          7.262164        5.67507     -1.53378
#
#     ArmAngleBR  ArmSlotBR  StrideLength  StrideLengthPercentHeight  \
# 0   104.899590  45.482530      6.234744                   0.959191
# 1    97.735704  45.769597      5.785254                   0.890039
# 8    97.114659  42.408580      6.060844                   0.932438
# 9    93.610172  39.368485      6.122093                   0.941860
# 10  103.514995  45.796271      6.146240                   0.945575
#
#     StrideWidth  TimeToPlate  PeakHipsVeloX  PeakPitchHandVeloX  DLHipRotMin  \
# 0      0.480582     1.794048       9.999728           74.488926   -57.704386
# 1      0.457357     1.727100       9.242676           73.800552   -57.276927
# 8      0.405218     1.779110       9.475445           73.169206   -57.308310
# 9      0.386986     1.692899       9.173078           75.840522   -55.105948
# 10     0.362848     1.771532       9.675753           75.468733   -58.000013
#
#      HSSepMin    PARotMax  PAScapRetMin  SLKneeFlexFP  PAElbowFlexBR  \
# 0  -59.436962  184.867034    -26.459514     33.558428      46.156729
# 1  -57.582635  183.756854    -48.689772     36.399829      48.956994
# 8  -57.557926  184.333399    -34.443572     38.298648      49.580683
# 9  -58.807858  181.659823    -31.512376     48.603188      49.594111
# 10 -57.375427  184.707496    -32.974904     38.112980      47.024741
#
#     SLKneeFlexBR  TorsoFBBR  TorsoSBBR  PeakMomDL  PeakMomSL  PeakMomTorso  \
# 0      61.829131  35.014744 -19.803716  59.076818  65.505386    178.474295
# 1      63.961833  33.845853 -20.061510  58.735936  61.773624    156.940774
# 8      60.398162  33.120254 -20.749445  61.317375  60.142862    161.546742
# 9      48.481361  35.040876 -20.347328  55.267417  63.746550    160.567349
# 10     62.273515  33.439625 -20.685694  61.908161  64.825324    166.495962
#
#     PeakMomLFA  PeakMomLUA  PeakMomPFA  PeakMomPUA  PeakMomTotalBody  \
# 0    14.589029   20.879261   25.940629   33.364805        316.155373
# 1    14.079443   19.891426   25.076940   32.904583        301.055415
# 8    13.645543   20.433823   25.186175   33.308831        313.563339
# 9    13.682870   20.536097   25.278245   33.548653        301.066706
# 10   13.436391   19.730564   25.970697   33.177811        328.538237
#
#     PeakMomTimeDL  PeakMomTimeSL  PeakMomTimeTorso  PeakMomTimeLFA  \
# 0       -0.225082      -0.278411         -0.071761       -0.118424
# 1       -0.198722      -0.422037         -0.125395       -0.148726
# 8       -0.205784      -0.289110         -0.135790       -0.119125
# 9       -0.202521      -0.359173         -0.122528       -0.115862
# 10      -0.206290      -0.372942         -0.136297       -0.122964
#
#     PeakMomTimeLUA  PeakMomTimePFA  PeakMomTimePUA  PeakMomTimeTotalBody  \
# 0        -0.115091       -0.005100       -0.051763             -0.078427
# 1        -0.118729       -0.002071       -0.048734             -0.135394
# 8        -0.119125       -0.012467       -0.045797             -0.139123
# 9        -0.112529       -0.005872       -0.049201             -0.135860
# 10       -0.116298       -0.006308       -0.046305             -0.139629
#
#     PeakPelvisRotVelo  PeakPelvisRotVeloTime  PeakChestRotVelo  \
# 0          580.134192              -0.138422       1051.790412
# 1          496.175175              -0.158725       1027.137579
# 8          456.371579              -0.119125       1045.288974
# 9          506.952667              -0.125861       1048.236004
# 10         451.663097              -0.119631       1044.058813
#
#     PeakChestRotVeloTime  PeakElbowExtVelo  PeakElbowExtVeloTime  \
# 0              -0.098426       1551.117321             -0.008433
# 1              -0.102063       1415.418660             -0.012071
# 8              -0.109125       1554.703469             -0.009134
# 9              -0.099197       1541.809433             -0.005872
# 10             -0.106299       1734.323423             -0.006308
#
#     PeakShoulderIRVelo  PeakShoulderIRVeloTime  PelvisChestPeakTimeDiff  \
# 0          2739.631800                0.014898                 0.039996
# 1          3244.898378                0.011261                 0.056662
# 8          3038.282142                0.014198                 0.010000
# 9          3254.025953                0.014126                 0.026664
# 10         3391.059334                0.017023                 0.013332
#
#     PeakSLKneeExtVelo  ClosingSpeed  ClosingTime  TimeFirstMove  \
# 0          -95.431603    519.237125     0.136655      -1.378319
# 1          -83.259474    466.447877     0.143322      -1.301965
# 8          -92.180262    477.177261     0.153320      -1.355687
# 9         -117.239887    483.774543     0.146653      -1.282426
# 10         -10.418899    517.529329     0.146654      -1.349521
#
#     TimeHandSeparation  TimePeakKneeLift  TimeFootPlant   TimeMER PitchType  \
# 0            -0.498392         -0.841697      -0.151755 -0.031765        FB
# 1            -0.532028         -0.802006      -0.155392 -0.035402        FB
# 8            -0.509092         -0.835731      -0.135790 -0.035798        FB
# 9            -0.482495         -0.809133      -0.089198 -0.032536        FB
# 10           -0.489598         -0.809569      -0.139629 -0.032972        FB
#
#        SpinRate  SpinDirection  InducedVertBreak  SpinEfficiency  PitchCount
# 0   2010.934814     198.274002         15.237906        0.981800           1
# 1   1991.656250     186.020004         18.172521        0.969281           1
# 8   2106.927734     200.289993         18.239483        0.967735           1
# 9   2181.846680     192.001999         15.462215        0.946546           1
# 10  2107.554443     199.561996         16.443963        0.960171           2

# %%
# Select relevant columns from the glossary
relevant_columns = ['ReleaseSpeed', 'ZoneSpeed', 'PitchVerticalApproachAngle', 'ReleaseExtension', 'ReleaseHeight', 'ReleaseSide', 'ArmAngleBR', 'ArmSlotBR', 'StrideLength', 'StrideLengthPercentHeight', 'StrideWidth', 'TimeToPlate', 'PeakHipsVeloX', 'PeakPitchHandVeloX', 'DLHipRotMin', 'HSSepMin', 'PARotMax', 'PAScapRetMin', 'SLKneeFlexFP', 'PAElbowFlexBR', 'SLKneeFlexBR', 'TorsoFBBR', 'TorsoSBBR', 'PeakMomDL', 'PeakMomSL', 'PeakMomTorso', 'PeakMomLFA', 'PeakMomLUA', 'PeakMomPFA', 'PeakMomPUA', 'PeakMomTotalBody', 'PeakPelvisRotVelo', 'PeakPelvisRotVeloTime', 'PeakChestRotVelo', 'PeakChestRotVeloTime', 'PeakElbowExtVelo', 'PeakElbowExtVeloTime', 'PeakShoulderIRVelo', 'PeakShoulderIRVeloTime', 'PelvisChestPeakTimeDiff', 'PeakSLKneeExtVelo', 'ClosingSpeed', 'ClosingTime', 'TimeFirstMove', 'TimeHandSeparation', 'TimePeakKneeLift', 'TimeFootPlant', 'TimeMER']

# Extract relevant data
pitching_data_relevant = fastball_only[relevant_columns].copy()

# %%
from sklearn.ensemble import RandomForestRegressor

# Separate features and target variable
X = pitching_data_relevant.drop('ReleaseSpeed', axis=1)  # Features
y = pitching_data_relevant['ReleaseSpeed']  # Target variable

# %% [markdown]
# ### Because we have some NaN values, we choose to drop these rows and not include them in our model. Another approach here would be the replace the NaN values with the relevant mean values.

# %%
# Drop rows with missing values
X_no_missing = X.dropna()

# Correspondingly, filter the target variable
y_no_missing = y[X.index.isin(X_no_missing.index)]

# %%
model = RandomForestRegressor()
# Fit the model with the data without missing values
model.fit(X_no_missing, y_no_missing)
# Out:
# RandomForestRegressor()

# %%
# Get feature importances
feature_importances = model.feature_importances_

# Create a DataFrame to visualize feature importances
feature_importance_df = pd.DataFrame({'Feature': X.columns, 'Importance': feature_importances})

# Sort features by importance
feature_importance_df = feature_importance_df.sort_values(by='Importance', ascending=False)

# Plot feature importances
plt.figure(figsize=(12, 10))
sns.barplot(x='Importance', y='Feature', data=feature_importance_df)
plt.title('Feature Importances for Fastball Variance')
plt.show()
